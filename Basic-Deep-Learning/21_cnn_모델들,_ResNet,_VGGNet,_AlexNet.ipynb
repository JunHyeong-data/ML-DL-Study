# %% [markdown]
# <a href="https://colab.research.google.com/github/JunHyeong-data/ML-DL-Study/blob/main/Basic-Deep-Learning/21_cnn_%EB%AA%A8%EB%8D%B8%EB%93%A4%2C_ResNet%2C_VGGNet%2C_AlexNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 아키텍처의 발전 과정 정리
#
# ## 1. 왜 CNN 아키텍처가 고민되는가?
#
# 컨볼루셔널 뉴럴 네트워크(CNN)를 배우다 보면 자연스럽게 다음과 같은 질문이 생긴다.
#
# - 컨볼루션 레이어는 **몇 개**를 써야 할까?
# - 스트라이드(stride)는 **얼마**가 적절할까?
# - 배치 정규화(Batch Normalization)는 **언제** 넣어야 할까?
# - 커널 크기는 **3×3, 5×5, 7×7 중 무엇이 좋은가?**
# - CNN 아키텍처를 **어떻게 구성해야 성능이 잘 나올까?**
#
# ### 결론
# 👉 **우리가 CNN 아키텍처를 처음부터 새로 설계할 필요는 없다.**
# 이미 검증된 유명 아키텍처들을 가져다 사용하는 것이 가장 합리적이다.
#
# ---
#
# ## 2. PyTorch에서 제공하는 이미지 분류 모델들
#
# PyTorch는 목적에 따라 다양한 사전 정의(predefined) 모델을 제공한다.
# 그중 우리는 **이미지 분류(Image Classification)** 모델에 집중한다.
#
# 대표적인 모델들:
# - :contentReference[oaicite:0]{index=0}
# - VGG
# - GoogLeNet
# - EfficientNet
# - ResNet 등
#
# 모델 비교 시 자주 보는 지표:
# - **Accuracy (정확도)**: 높을수록 좋음
# - **FLOPs (연산량)**: 적을수록 효율적
# - **Parameter 수**: 모델 크기
#
# > 보통 그래프에서
# > - y축: Accuracy
# > - x축: FLOPs
# > - 원의 크기: 파라미터 수
#
# ---
#
# ## 3. AlexNet (2012)
#
# ### 특징
# - 컨볼루션 레이어: 5개
# - 구조 자체는 **지금 기준으로 매우 단순**
# - 우리가 CNN 기초에서 배운 내용 대부분이 이미 포함됨
#
# 👉 역사적으로 중요하지만, 구조적으로 특별히 복잡하지는 않다.
#
# ---
#
# ## 4. VGGNet (2014)
#
# 대표 모델:
# - :contentReference[oaicite:1]{index=1}
# - VGG-16, VGG-19
#
# ### 핵심 특징
# 1. **네트워크가 매우 깊어짐**
#    - 16개, 19개의 레이어
# 2. **모든 컨볼루션 커널을 3×3으로 통일**
# 3. **채널 수를 점진적으로 증가**
#    - 64 → 128 → 256 → 512
# 4. **Batch Normalization이 없던 시절의 모델**
#
# ### 의미
# - 네트워크가 깊어질수록 **비선형성(non-linearity)**이 증가
# - 결과적으로 **분류 성능 향상**
#
# ⚠️ 단점:
# - 파라미터 수 많음
# - 연산량 큼
# - 현재 기준으로는 효율이 좋지 않음
#
# ---
#
# ## 5. GoogLeNet (Inception, 2014)
#
# - :contentReference[oaicite:2]{index=2}
# - 총 **22개 레이어**
#
# ### 핵심 아이디어
# - 단순히 깊게 만드는 것이 아니라 **연산을 효율적으로**
# - 동일한 형태의 **Inception Module**을 반복적으로 쌓음
# - 여러 커널 크기(1×1, 3×3, 5×5)를 병렬로 사용
#
# ### 보조 분류기 (Auxiliary Classifier)
# - 네트워크가 깊어지며 **그래디언트 소실 문제 발생**
# - 중간중간 보조 분류기를 넣어 **그래디언트 전달을 보조**
#
# 👉 정확도는 약간 낮아졌지만,
# - 연산량 감소
# - 모델 크기 감소
# - AlexNet보다도 작은 모델 사이즈 달성
#
# ---
#
# ## 6. ResNet (2015) — 핵심 전환점
#
# - :contentReference[oaicite:3]{index=3}
# - 최대 **152 레이어**까지 성공적으로 학습
#
# ### 문제의식
# - 단순히 깊게 만들면:
#   - 성능이 오히려 떨어짐
#   - 백프로파게이션이 제대로 동작하지 않음
#
# ### 해결책: Skip Connection (Residual Connection)
#
# \[
# y = F(x) + x
# \]
#
# - 입력을 그대로 더해주는 **아이덴티티 경로**
# - 네트워크가 학습해야 할 것은 **잔차(residual)**
#
# ### 직관적 해석
# - 만약 출력이 입력과 같아야 한다면?
#   - **아무것도 학습하지 않아도 된다**
# - 즉, **최악의 경우 성능이 나빠지지 않음**
#
# ---
#
# ## 7. Residual Block 구조
#
# ### Basic Residual Block
# - Conv → BN → ReLU
# - Conv → BN
# - 입력(x)을 출력에 더함
#
# ### Bottleneck Residual Block
# - 1×1 → 3×3 → 1×1 구조
# - 연산 효율 증가
# - ResNet-50 / 101 / 152에서 사용
#
# ### 채널 수가 바뀔 때
# - shortcut 경로에도 **1×1 convolution** 필요
#
# ---
#
# ## 8. 이후의 발전
#
# - ResNet 이후 대부분의 CNN은 **Residual 구조 기반**
# - MobileNet:
#   - 연산량 최소화
#   - 모바일·엣지 디바이스용
# - EfficientNet:
#   - 깊이, 너비, 해상도를 균형 있게 확장
#
# ---
#
# ## 9. CNN 이후: Vision Transformer
#
# - CNN 이후 등장한 새로운 패러다임: :contentReference[oaicite:4]{index=4}
# - 하지만 여전히:
#   - 많은 **클래식 컴퓨터 비전 문제**
#   - 실무·산업 환경
# 에서는 CNN 계열이 매우 강력함
#
# ---
#
# ## 10. 정리
#
# - CNN 아키텍처는 **무작정 설계하는 것이 아니다**
# - 이미 검증된 구조를 이해하고 활용하는 것이 핵심
# - AlexNet → VGG → GoogLeNet → ResNet 흐름은
#   **딥러닝 설계 철학의 진화 과정**
#
# 다음 주제:
# 👉 **Transfer Learning (전이 학습)**

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

if torch.backends.mps.is_available():
    my_device = torch.device('mps')
elif torch.cuda.is_available():
    my_device = torch.device('cuda')
else:
    my_device = torch.device('cpu')

print(my_device)
# Out:
# cpu

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(30),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=8)

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=8)
# Out:
# 100%|██████████| 170M/170M [00:05<00:00, 32.8MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)

        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Identity()

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out



class SuperSimpleResNet(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()

        self.down_spatial = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )

        self.features = nn.Sequential(
            ResidualBlock(64, 64),
            ResidualBlock(64, 64),
            ResidualBlock(64, 64),
            ResidualBlock(64, 64),
            ResidualBlock(64, 64),
        )

        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.classifier = nn.Linear(64, num_classes)

    def forward(self, x):
        x = self.down_spatial(x)
        x = self.features(x)
        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Instantiate the network
net = SuperSimpleResNet(num_classes=10)

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.0001)

# %%
net.to(my_device)
num_epochs = 100
for epoch in range(num_epochs):
    net.train()
    for batch_idx, (data, label) in enumerate(trainloader):
        data, label = data.to(my_device), label.to(my_device)
        scores = net(data)
        loss = criterion(scores, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    net.eval()
    val_loss = 0.0
    correct = 0
    with torch.no_grad():
        for data, label in testloader:
            data, label = data.to(my_device), label.to(my_device)
            scores = net(data)
            loss = criterion(scores, label)
            val_loss += loss.item() * data.size(0)

            predicted = scores.argmax(dim=1)
            correct += predicted.eq(label).sum().item()

    val_loss /= len(testloader.dataset)
    val_accuracy = 100. * correct / len(testloader.dataset)

    print(f"Epoch [{epoch + 1}/{num_epochs}], Training Loss: {loss.item():.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%")
# Out:
# Epoch [1/100], Training Loss: 1.3098, Validation Loss: 1.6825, Validation Accuracy: 39.28%
# Epoch [2/100], Training Loss: 0.9551, Validation Loss: 1.4712, Validation Accuracy: 47.23%
# Epoch [3/100], Training Loss: 0.7022, Validation Loss: 1.3942, Validation Accuracy: 49.91%

# %% [markdown]
# ✅ Residual Learning
# 𝐻
# (
# 𝑥
# )
# =
# 𝐹
# (
# 𝑥
# )
# +
# 𝑥
# H(x)=F(x)+x
#
# 즉,
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝐻
# (
# 𝑥
# )
# −
# 𝑥
# F(x)=H(x)−x
#
# 👉 네트워크는 ‘정답’이 아니라 ‘차이’만 학습
